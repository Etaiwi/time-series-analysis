# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import os
#import plotly.io as pio
#pio.templates.default = "plotly_white"
#pio.kaleido.scope.mathjax = None
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from itertools import cycle
#%load_ext autoreload
#%autoreload 2
np.random.seed(123)
"""
tqdm.pandas() is a function that enables the tqdm progress bar library to
integrate directly with pandas DataFrame and Series operations.
By calling this function once, you register new methods like progress_apply(),
progress_map(), and progress_applymap() that can be used in place of the
standard pandas methods (apply(), map(), etc.) to display a smart progress bar.
"""
tqdm.pandas()

# %% [markdown]
# ### Pandas Datetime Operations, Indexing, and Slicing – A refresher
#
# Before we start wrangling our data, let's quickly look at a few pandas concepts which will be useful. And for that let's pick an easy, well formatted stock exchange price dataset from UCI ML Repo.

# %%
df = pd.read_excel("data_akbilgic.xlsx", skiprows=1) #date_format=False

df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning:
#
# Unknown extension is not supported and will be removed
#         date       ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# 0 2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000
# 1 2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2 2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 3 2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 4 2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#     BOVESPA        EU        EM
# 0  0.031190  0.012698  0.028524
# 1  0.018920  0.011341  0.008773
# 2 -0.035899 -0.017073 -0.020015
# 3  0.028283 -0.005561 -0.019424
# 4 -0.009764 -0.010989 -0.007802

# %% [markdown]
# #### Converting date columns to pd.Timestamp/DatetimeIndex
# First, we need to convert the date columns in `str` to `pd.Timestamp` and we can use [`pd.to_datetime`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) to accomplish that.

# %%
print(df.dtypes)
# Out:
# date       datetime64[ns]
# ISE               float64
# ISE.1             float64
# SP                float64
# DAX               float64
# FTSE              float64
# NIKKEI            float64
# BOVESPA           float64
# EU                float64
# EM                float64
# dtype: object

# %%
pd.to_datetime("13-4-1987").strftime("%d, %B %Y")
# Out:
# /tmp/ipykernel_1266/3296306359.py:1: UserWarning:
#
# Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
# '13, April 1987'

# %% [markdown]
# Now let's look at a case where the automatic parsing fails. The date is 4th January, 1987.

# %%
pd.to_datetime("4-1-1987").strftime("%d, %B %Y")
# Out:
# '01, April 1987'

# %% [markdown]
# Now, anyone can make that mistake because we are not telling the computer whether month comes first or day comes first and pandas assumes month coming first. Let's rectify that.

# %%
pd.to_datetime("4-1-1987", dayfirst=True).strftime("%d, %B %Y")
# Out:
# '04, January 1987'

# %% [markdown]
# Another case where the automatic date parsing fails is when the date string is in a non-standard form. There we can give a strftime formatted string to help pandas parse the dates correctly
#
# Note that
#
# %b: Abbreviated month name (e.g., Jan, Feb).
#
# %B: Full month name (e.g., January, February).
#
# %m: Month as a zero-padded number (e.g., 01, 02).

# %%
pd.to_datetime("4|1|1987", format="%d|%m|%Y").strftime("%d, %B %Y")
# Out:
# '04, January 1987'

# %% [markdown]
# **Best Practice** - Wherever possible, use the `format` or at least `dayfirst` and `yearfirst` parameters to make sure pandas is understanding the dates correctly. `format` is a standard strftime formatted string, for e.g., "%Y-%m-%d". For full table of codes and their meanings refer [here](https://docs.python.org/3/library/datetime.html).

# %%
df['date'] = pd.to_datetime(df['date'], yearfirst=True)
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.date.min(),df.date.max()
# Out:
# (Timestamp('2009-01-05 00:00:00'), Timestamp('2011-02-22 00:00:00'))

# %% [markdown]
# #### dt accessor and datetime properties

# %%
df.head()
# Out:
#         date       ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# 0 2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000
# 1 2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2 2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 3 2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 4 2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#     BOVESPA        EU        EM
# 0  0.031190  0.012698  0.028524
# 1  0.018920  0.011341  0.008773
# 2 -0.035899 -0.017073 -0.020015
# 3  0.028283 -0.005561 -0.019424
# 4 -0.009764 -0.010989 -0.007802

# %%
print(f"""
Date: {df.date.iloc[0]} # The full datetime object
Day of year: {df.date.dt.day_of_year.iloc[0]} # The day of the year (1-365)
Day of week: {df.date.dt.dayofweek.iloc[0]} # The day of the week (0=Monday, 6=Sunday)
Month: {df.date.dt.month.iloc[0]} # The month as a number (1-12)
Month Name: {df.date.dt.month_name().iloc[0]} # The full name of the month (e.g., January)
Quarter: {df.date.dt.quarter.iloc[0]} # The quarter of the year (1-4)
Year: {df.date.dt.year.iloc[0]} # The year
ISO Week: {df.date.dt.isocalendar().week.iloc[0]} # The ISO week number
""")
# Out:
# Date: 2009-01-05 00:00:00 # The full datetime object
# Day of year: 5 # The day of the year (1-365)
# Day of week: 0 # The day of the week (0=Monday, 6=Sunday)
# Month: 1 # The month as a number (1-12)
# Month Name: January # The full name of the month (e.g., January)
# Quarter: 1 # The quarter of the year (1-4)
# Year: 2009 # The year
# ISO Week: 2 # The ISO week number

# %% [markdown]
# #### Slicing and Indexing
#
# If you set the date column as the index of the dataframe, all kinds of helpful slicing and indexing is possible.

# %%
df.set_index("date", inplace=True)

# Select all data after 2010-01-04(including)
df["2010-01-04":]
# Out:
#                  ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# date
# 2010-01-04  0.010229  0.014478  0.015916  0.000000  0.016018  0.000000
# 2010-01-05  0.013898  0.024019  0.003111 -0.002722  0.004028  0.002535
# 2010-01-06  0.007957  0.005706  0.000545  0.000409  0.001357  0.004635
# 2010-01-07  0.007772  0.007498  0.003993 -0.002484 -0.000597 -0.004650
# 2010-01-08 -0.003189  0.000835  0.002878  0.003027  0.001356  0.010862
# ...              ...       ...       ...       ...       ...       ...
# 2011-02-16  0.008599  0.013400  0.006238  0.001925  0.007952  0.005717
# 2011-02-17  0.009310  0.015977  0.003071 -0.001186  0.000345  0.002620
# 2011-02-18  0.000191 -0.001653  0.001923  0.002872 -0.000723  0.000568
# 2011-02-21 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275  0.001358
# 2011-02-22 -0.007246 -0.019442  0.000000 -0.000473 -0.002997 -0.017920
#
#              BOVESPA        EU        EM
# date
# 2010-01-04  0.000000  0.016778  0.008399
# 2010-01-05  0.002780  0.001316  0.008067
# 2010-01-06  0.006938  0.000586  0.005330
# 2010-01-07 -0.003938 -0.000360 -0.006375
# 2010-01-08 -0.002672  0.003554  0.001229
# ...              ...       ...       ...
#
#              BOVESPA        EU        EM
# date
# 2010-01-04  0.000000  0.016778  0.008399
# 2010-01-05  0.002780  0.001316  0.008067
# 2010-01-06  0.006938  0.000586  0.005330
# 2010-01-07 -0.003938 -0.000360 -0.006375
# 2010-01-08 -0.002672  0.003554  0.001229
# ...              ...       ...       ...
# 2010-06-24 -0.018948 -0.017801 -0.006717
# 2010-06-25  0.013778 -0.007954 -0.002311
# 2010-06-28 -0.009283  0.009125  0.000540
# 2010-06-29 -0.035613 -0.034903 -0.021033
# 2010-06-30 -0.016955  0.002202 -0.006962
#
# [126 rows x 9 columns]

# %% [markdown]
# #### Sequences and Offsets of Dates
#
# In addition to the semantic information and intelligent indexing and slicing, pandas also has tools to create date sequences and even manipulate date sequences.

# %%
# Specifying start and end dates with frequency
pd.date_range(start="2018-01-20", end="2018-01-23", freq="D").astype(str).tolist()
# Out:
# ['2018-01-20', '2018-01-21', '2018-01-22', '2018-01-23']

# %%
# Specifying start and number of periods to generate in the given frequency
pd.date_range(start="2018-01-20", periods=4, freq="D").astype(str).tolist()
# Out:
# ['2018-01-20', '2018-01-21', '2018-01-22', '2018-01-23']

# %%
# Generating a date sequence with every 2 days
pd.date_range(start="2018-01-20", periods=4, freq="2D").astype(str).tolist()
# Out:
# ['2018-01-20', '2018-01-22', '2018-01-24', '2018-01-26']

# %%
# Generating a date sequence every month. By default it starts with Month end
pd.date_range(start="2018-01-20", periods=4, freq="M").astype(str).tolist()
# Out:
# /tmp/ipykernel_1266/1486085351.py:2: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
# ['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30']

# %%
# Generating a date sequence every month, but month start
pd.date_range(start="2018-01-20", periods=4, freq="MS").astype(str).tolist()
# Out:
# ['2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01']

# %% [markdown]
# We can also add or subtract days/months/etc. to dates using TimeDelta

# %%
# Add four days to the date range
(pd.date_range(start="2018-01-20", end="2018-01-23", freq="D") + pd.Timedelta(4, unit="D")).astype(str).tolist()
# Out:
# ['2018-01-24', '2018-01-25', '2018-01-26', '2018-01-27']

# %%
# Add four weeks to the date range
(pd.date_range(start="2018-01-20", end="2018-01-23", freq="D") + pd.Timedelta(4, unit="W")).astype(str).tolist()
# Out:
# ['2018-02-17', '2018-02-18', '2018-02-19', '2018-02-20']

# %% [markdown]
# #### Resampling, Shifting, Rolling Window, and Expanding Window Operations
#
# **Resampling**
# Resampling is a powerful operation which let's you aggregate and disaggregate along the temporal dimension.

# %%
# Resampling at Month Start and taking the mean
m_df = df[['ISE']].resample("MS").mean()
display(m_df.head())
# Resampling at Week(starting Monday) and taking the mean
w_df = df[['ISE']].resample("W-MON").mean()
display(w_df.head())
# Out:
#                  ISE
# date
# 2009-01-01 -0.002024
# 2009-02-01 -0.003820
# 2009-03-01  0.003175
# 2009-04-01  0.009799
# 2009-05-01  0.005297
#                  ISE
# date
# 2009-01-05  0.035754
# 2009-01-12 -0.016995
# 2009-01-19 -0.005143
# 2009-01-26  0.007167
# 2009-02-02 -0.005458

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=
00:00:00","2009-07-03T00:00:00","2009-07-06T00:00:00","2009-07-07T00:00:00","2009-07-08T00:00:00","2009-07-09T00:00:00","2009-07-10T00:00:00","2009-07-13T00:00:00","2009-07-14T00:00:00","2009-07-15T00:00:00","2009-07-16T00:00:00","2009-07-17T00:00:00","2009-07-20T00:00:00","2009-07-21T00:00:00","2009-07-22T00:00:00","2009-07-23T00:00:00","2009-07-24T00:00:00","2009-07-27T00:00:00","2009-07-28T00:00:00","2009-07-29T00:00:00","2009-07-30T00:00:00","2009-07-31T00:00:00","2009-08-03T00:00:00","2009-08-04T00:00:00","2009-08-05T00:00:00","2009-08-06T00:00:00","2009-08-07T00:00:00","2009-08-10T00:00:00","2009-08-11T00: ...

# %% [markdown]
# **Shift**
# Shifting a series along the temporal dimension is another valuable operation

# %%
plot_df = df.loc[:, ['ISE']]
# Shift forward by one day
plot_df['ISE_shift_1'] = df[["ISE"]].shift(1)
# Shift backward by one day
plot_df['ISE_shift_-1'] = df[["ISE"]].shift(-1)

plot_df = plot_df.dropna().iloc[20:40].reset_index()
plot_df = pd.melt(plot_df, id_vars="date")
fig = px.line(plot_df, x="date", y="value", color="variable", line_dash="variable", template="plotly_white")
fig.update_layout(
    yaxis=dict(tickfont=dict(size=15)),
    xaxis=dict(tickfont=dict(size=15)),
    legend=dict(font=dict(size=15)),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4b90d4fe-b409-4c33-9878-835a617bc76b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b90d4fe-b409-4c33-9878-835a617bc76b")) {                    Plotly.newPlot(                        "4b90d4fe-b409-4c33-9878-835a617bc76b",                        [{"hovertemplate":"variable=ISE\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE","orientation":"v","showlegend":true,"x":["2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-03-02T00:00:00"],"xaxis":"x","y":[0.015279487,0.018577796,-0.014132879,0.036607044,0.011353209,-0.040542021,-0.022105644,-0.014888368,0.007026745,-0.011494996,-0.041136038,-0.002631499,0.024654643,-0.03584061,0.017303168,0.001725406,0.004975853,0.000671759,-0.005891895,-0.013689039],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=ISE_shift_1\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE_shift_1","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE_shift_1","orientation":"v","showlegend":true,"x":["2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-03-02T00:00:00"],"xaxis":"x","y":[-0.025919141,0.015279487,0.018577796,-0.014132879,0.036607044,0.011353209,-0.040542021,-0.022105644,-0.014888368,0.007026745,-0.011494996,-0.041136038,-0.002631499,0.024654643,-0.03584061,0.017303168,0.001725406,0.004975853,0.000671759,-0.005891895],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=ISE_shift_-1\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE_shift_-1","line":{"color":"#00cc96","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE_shift_-1","orientation":"v","showlegend":true,"x":["2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-03-02T00:00:00"],"xaxis":"x","y":[0.018577796,-0.014132879,0.036607044,0.011353209,-0.040542021,-0.022105644,-0.014888368,0.007026745,-0.011494996,-0.041136038,-0.002631499,0.024654643,-0.03584061,0.017303168,0.001725406,0.004975853,0.000671759,-0.005891895,-0.013689039,0.002192959],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666 ...

# %% [markdown]
# **Rolling and Expanding Window**
#
# There are strong use cases to calculate some statistics on a rolling or expanding window.

# %%
plot_df = df.loc[:, ['ISE']]
# Moving Average of 5 days
plot_df["ISE_rolling_5_mean"] = df[['ISE']].rolling(window=5).mean()

plot_df = plot_df.dropna().iloc[20:50].reset_index()
plot_df = pd.melt(plot_df, id_vars="date")
fig = px.line(plot_df, x="date", y="value", line_dash="variable", template="plotly_white")
fig.update_layout(
    yaxis=dict(tickfont=dict(size=15)),
    xaxis=dict(tickfont=dict(size=15)),
    legend=dict(font=dict(size=15)),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="178a38cc-c23f-43ba-960e-0d25a6c3955c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("178a38cc-c23f-43ba-960e-0d25a6c3955c")) {                    Plotly.newPlot(                        "178a38cc-c23f-43ba-960e-0d25a6c3955c",                        [{"hovertemplate":"variable=ISE\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE","orientation":"v","showlegend":true,"x":["2009-02-06T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-03-02T00:00:00","2009-03-03T00:00:00","2009-03-04T00:00:00","2009-03-05T00:00:00","2009-03-06T00:00:00","2009-03-09T00:00:00","2009-03-10T00:00:00","2009-03-11T00:00:00","2009-03-12T00:00:00","2009-03-13T00:00:00","2009-03-16T00:00:00","2009-03-17T00:00:00","2009-03-18T00:00:00","2009-03-19T00:00:00"],"xaxis":"x","y":[0.036607044,0.011353209,-0.040542021,-0.022105644,-0.014888368,0.007026745,-0.011494996,-0.041136038,-0.002631499,0.024654643,-0.03584061,0.017303168,0.001725406,0.004975853,0.000671759,-0.005891895,-0.013689039,0.002192959,0.007913215,-0.03852223,0.007958798,-0.007133473,0.011234009,-0.001410361,0.010974424,0.003213253,0.000214245,-0.00711875,0.001891803,0.019874248],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=ISE_rolling_5_mean\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE_rolling_5_mean","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE_rolling_5_mean","orientation":"v","showlegend":true,"x":["2009-02-06T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-03-02T00:00:00","2009-03-03T00:00:00","2009-03-04T00:00:00","2009-03-05T00:00:00","2009-03-06T00:00:00","2009-03-09T00:00:00","2009-03-10T00:00:00","2009-03-11T00:00:00","2009-03-12T00:00:00","2009-03-13T00:00:00","2009-03-16T00:00:00","2009-03-17T00:00:00","2009-03-18T00:00:00","2009-03-19T00:00:00"],"xaxis":"x","y":[0.006082461400000001,0.013536931400000002,0.0023726298000000022,-0.005764058199999998,-0.005915155999999999,-0.011831215799999998,-0.016400856799999995,-0.016519660199999998,-0.012624831199999997,-0.004716228999999998,-0.013289699999999998,-0.007530067199999997,0.0010422216000000029,0.002563692000000003,-0.0022328847999999973,0.003756858200000003,-0.002441583199999997,-0.002348072599999997,-0.0017606001999999972,-0.009599397999999997,-0.006829259399999996,-0.005518146199999996,-0.003709936199999997,-0.005574651399999997,0.0043246794000000015,0.0033755704000000024,0.004845114000000003,0.0011745622000000028,0.0018349950000000025,0.0036149598000000025],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88 ...

# %%
plot_df = df.loc[:, ['ISE']]
# Moving Average of 30 days
plot_df["ISE_rolling_30_mean"] = df[['ISE']].rolling(window=120).mean()
# Expanding Average
plot_df["ISE_expanding_mean"] = df[['ISE']].expanding().mean()
plot_df.drop(columns='ISE', inplace=True)
plot_df = plot_df.dropna().reset_index()
plot_df = pd.melt(plot_df, id_vars="date")
fig = px.line(plot_df, x="date", y="value", line_dash="variable", template="plotly_white")
fig.update_layout(
    yaxis=dict(tickfont=dict(size=15)),
    xaxis=dict(tickfont=dict(size=15)),
    legend=dict(font=dict(size=15)),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="acd5203d-b06c-4a5f-98e8-6cb016f32ccf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acd5203d-b06c-4a5f-98e8-6cb016f32ccf")) {                    Plotly.newPlot(                        "acd5203d-b06c-4a5f-98e8-6cb016f32ccf",                        [{"hovertemplate":"variable=ISE_rolling_30_mean\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISE_rolling_30_mean","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISE_rolling_30_mean","orientation":"v","showlegend":true,"x":["2009-06-24T00:00:00","2009-06-25T00:00:00","2009-06-26T00:00:00","2009-06-29T00:00:00","2009-06-30T00:00:00","2009-07-01T00:00:00","2009-07-02T00:00:00","2009-07-03T00:00:00","2009-07-06T00:00:00","2009-07-07T00:00:00","2009-07-08T00:00:00","2009-07-09T00:00:00","2009-07-10T00:00:00","2009-07-13T00:00:00","2009-07-14T00:00:00","2009-07-15T00:00:00","2009-07-16T00:00:00","2009-07-17T00:00:00","2009-07-20T00:00:00","2009-07-21T00:00:00","2009-07-22T00:00:00","2009-07-23T00:00:00","2009-07-24T00:00:00","2009-07-27T00:00:00","2009-07-28T00:00:00","2009-07-29T00:00:00","2009-07-30T00:00:00","2009-07-31T00:00:00","2009-08-03T00:00:00","2009-08-04T00:00:00","2009-08-05T00:00:00","2009-08-06T00:00:00","2009-08-07T00:00:00","2009-08-10T00:00:00","2009-08-11T00:00:00","2009-08-12T00:00:00","2009-08-13T00:00:00","2009-08-14T00:00:00","2009-08-17T00:00:00","2009-08-18T00:00:00","2009-08-19T00:00:00","2009-08-20T00:00:00","2009-08-21T00:00:00","2009-08-24T00:00:00","2009-08-25T00:00:00","2009-08-26T00:00:00","2009-08-27T00:00:00","2009-08-28T00:00:00","2009-08-31T00:00:00","2009-09-01T00:00:00","2009-09-02T00:00:00","2009-09-03T00:00:00","2009-09-04T00:00:00","2009-09-07T00:00:00","2009-09-08T00:00:00","2009-09-09T00:00:00","2009-09-10T00:00:00","2009-09-11T00:00:00","2009-09-14T00:00:00","2009-09-15T00:00:00","2009-09-16T00:00:00","2009-09-17T00:00:00","2009-09-18T00:00:00","2009-09-23T00:00:00","2009-09-24T00:00:00","2009-09-25T00:00:00","2009-09-28T00:00:00","2009-09-29T00:00:00","2009-09-30T00:00:00","2009-10-01T00:00:00","2009-10-02T00:00:00","2009-10-05T00:00:00","2009-10-06T00:00:00","2009-10-07T00:00:00","2009-10-08T00:00:00","2009-10-09T00:00:00","2009-10-12T00:00:00","2009-10-13T00:00:00","2009-10-14T00:00:00","2009-10-15T00:00:00","2009-10-16T00:00:00","2009-10-19T00:00:00","2009-10-20T00:00:00","2009-10-21T00:00:00","2009-10-22T00:00:00","2009-10-23T00:00:00","2009-10-26T00:00:00","2009-10-27T00:00:00","2009-10-28T00:00:00","2009-10-30T00:00:00","2009-11-02T00:00:00","2009-11-03T00:00:00","2009-11-04T00:00:00","2009-11-05T00:00:00","2009-11-06T00:00:00","2009-11-09T00:00:00","2009-11-10T00:00:00","2009-11-11T00:00:00","2009-11-12T00:00:00","2009-11-13T00:00:00","2009-11-16T00:00:00","2009-11-17T00:00:00","2009-11-18T00:00:00","2009-11-19T00:00:00","2009-11-20T00:00:00","2009-11-23T00:00:00","2009-11-24T00:00:00","2009-11-25T00:00:00","2009-12-01T00:00:00","2009-12-02T00:00:00","2009-12-03T00:00:00","2009-12-04T00:00:00","2009-12-07T00:00:00","2009-12-08T00:00:00","2009-12-09T00:00:00","2009-12-10T00:00:00","2009-12-11T00:00:00","2009-12-14T00:00:00","2009-12-15T00:00:00","2009-12-16T00:00:00","2009-12-17T00:00:00","2009-12-18T00:00:00","2009-12-21T00:00:00","2009-12-22T00:00:00","2009-12-23T00:00:00","2009-12-24T00:00:00","2009-12-25T00:00:00","2009-12-28T00:00:00","2009-12-29T00:00:00","2009-12-30T00:00:00","2009-12-31T00:00:00","2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-0 ...

# %%
del plot_df, df, w_df

# %% [markdown]
# ### Missing Value Treatment

# %%
def format_plot(fig, legends, font_size=15, title_font_size=20):
    names = cycle(legends)
    fig.for_each_trace(lambda t: t.update(name=next(names)))
    fig.update_layout(
        autosize=False,
        width=900,
        height=500,
        title={"x": 0.5, "xanchor": "center", "yanchor": "top"},
        titlefont={"size": title_font_size},
        legend_title=None,
        legend=dict(
            font=dict(size=font_size),
            orientation="h",
            yanchor="bottom",
            y=0.98,
            xanchor="right",
            x=1,
        ),
        yaxis=dict(
            title_text="Value",
            titlefont=dict(size=font_size),
            tickfont=dict(size=font_size),
        ),
        xaxis=dict(
            title_text="Day",
            titlefont=dict(size=font_size),
            tickfont=dict(size=font_size),
        ),
    )
    return fig

# %%
df = pd.read_csv("au_airquality.csv", sep=",")
df.head()
# Out:
#      name                              gps                 datetime  no2  \
# 0  Monash  \n,  \n(-35.418302, 149.094018)  2024-03-18T16:00:00.000  NaN
# 1  Monash  \n,  \n(-35.418302, 149.094018)  2024-02-22T16:00:00.000  NaN
# 2  Monash  \n,  \n(-35.418302, 149.094018)  2024-02-15T16:00:00.000  NaN
# 3  Monash  \n,  \n(-35.418302, 149.094018)  2024-02-10T16:00:00.000  NaN
# 4  Florey  \n,  \n(-35.220606, 149.043539)  2024-01-15T16:00:00.000  NaN
#
#    o3_1hr  o3_4hr  o3_8hr  co  pm10_1_hr  pm2_5_1_hr  ...  aqi_co  aqi_no2  \
# 0     NaN     NaN   0.019 NaN        8.5         2.1  ...     NaN      NaN
# 1     NaN     NaN   0.024 NaN        0.0         0.0  ...     NaN      NaN
# 2     NaN     NaN   0.016 NaN        9.4         NaN  ...     NaN      NaN
# 3     NaN     NaN   0.018 NaN        5.4         4.1  ...     NaN      NaN
# 4     NaN     NaN   0.017 NaN        2.6         1.4  ...     NaN      NaN
#
#    aqi_o3_1hr  aqi_o3_4hr  aqi_o3_8hr  aqi_pm10  aqi_pm2_5  aqi_site  \
# 0         NaN         NaN         NaN       7.0        7.0       NaN
# 1         NaN         NaN         NaN      11.0        9.0       NaN
# 2         NaN         NaN         NaN      11.0       16.0       NaN
# 3         NaN         NaN         NaN      18.0       23.0       NaN
# 4         NaN         NaN         NaN      12.0       14.0      14.0
#
#                       date   time
# 0  2024-03-18T00:00:00.000  16:00
# 1  2024-02-22T00:00:00.000  16:00
# 2  2024-02-15T00:00:00.000  16:00
# 3  2024-02-10T00:00:00.000  16:00
# 4  2024-01-15T00:00:00.000  16:00
#
# [5 rows x 22 columns]

# %%
#Selecting one location and pm2.5
df = df.loc[df.name=="Monash", ['datetime', 'pm2_5_1_hr']]
df.dtypes
# Out:
# datetime       object
# pm2_5_1_hr    float64
# dtype: object

# %%
df.datetime = pd.to_datetime(df.datetime)
df.sort_values("datetime", inplace=True)
df.set_index("datetime", inplace=True)
df.head()
# Out:
#                      pm2_5_1_hr
# datetime
# 2012-08-31 16:00:00         NaN
# 2013-03-18 16:00:00         NaN
# 2014-02-24 21:00:00         NaN
# 2014-04-24 16:00:00         NaN
# 2015-01-28 05:00:00         NaN

# %%
dates = df.index.unique().tolist()
null_dates = dates[-10:-7]
# introducing missing values by nulling out the values
df.loc[null_dates, "pm2_5_1_hr"] = np.nan

# %% [markdown]
# **We have introduced a few missing values between min(null_dates)  and max(null_dates) in the PM2.5 column**

# %%
df = df.loc[dates[-15:-5], "pm2_5_1_hr"].to_frame()
fig = px.line(df, x=df.index, y="pm2_5_1_hr", title="Missing Values in PM2.5")
fig = format_plot(fig, ["Original"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b8b95d0-9058-4a3f-b7b1-9733dedd6cc3" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b8b95d0-9058-4a3f-b7b1-9733dedd6cc3")) {                    Plotly.newPlot(                        "6b8b95d0-9058-4a3f-b7b1-9733dedd6cc3",                        [{"hovertemplate":"datetime=%{x}\u003cbr\u003epm2_5_1_hr=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original","orientation":"v","showlegend":false,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,null,null,null,8.5,18.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}, ...

# %% [markdown]
# ## Last Observation Carried Forward (Forward Fill), Next Observation Carried Backward (Backward Fill) and Mean Value Fill

# %%
_df = df.copy()
#Forward Fill
_df["ffill"] = _df['pm2_5_1_hr'].ffill()
# Backward Fill
_df["bfill"] = _df['pm2_5_1_hr'].bfill()
# Mean Value Fil
_df["mean_value"] = _df['pm2_5_1_hr'].fillna(df['pm2_5_1_hr'].mean())

# %%
#Plotting
plot_df = pd.melt(_df.reset_index(), id_vars="datetime", var_name="series")
fig = px.line(plot_df, x="datetime", y=["value"], line_dash="series", title="Forward, Backward, and Mean Value Fill")
fig = format_plot(fig, ['Original', 'Forward Fill', 'Backward Fill', "Mean Value Fill"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d3d842ae-f834-497a-bd26-2f39ae33a2e6" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3d842ae-f834-497a-bd26-2f39ae33a2e6")) {                    Plotly.newPlot(                        "d3d842ae-f834-497a-bd26-2f39ae33a2e6",                        [{"hovertemplate":"variable=value\u003cbr\u003eseries=pm2_5_1_hr\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, pm2_5_1_hr","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,null,null,null,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=ffill\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, ffill","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Forward Fill","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,7.6,7.6,7.6,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=bfill\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, bfill","line":{"color":"#636efa","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines","name":"Backward Fill","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,8.5,8.5,8.5,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=mean_value\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, mean_value","line":{"color":"#636efa","dash":"longdash"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mean Value Fill","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,7.071428571428571,7.071428571428571,7.071428571428571,8.5,18.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0. ...

# %% [markdown]
# ## Interpolation

# %%
_df = df.copy()
_df["linear_interpolation"] = _df['pm2_5_1_hr'].interpolate(method="linear")
_df["nearest_interpolation"] = _df['pm2_5_1_hr'].interpolate(method="nearest")

# %%
#Plotting
plot_df = pd.melt(_df.reset_index(), id_vars="datetime", var_name="series")
fig = px.line(plot_df, x="datetime", y=["value"], line_dash="series", title="Linear and Nearest Interpolation")
fig = format_plot(fig, ['Original', "Linear Interpolation", "Nearest Interpolation"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6841ba2d-084c-486b-a353-4f540956cea9" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6841ba2d-084c-486b-a353-4f540956cea9")) {                    Plotly.newPlot(                        "6841ba2d-084c-486b-a353-4f540956cea9",                        [{"hovertemplate":"variable=value\u003cbr\u003eseries=pm2_5_1_hr\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, pm2_5_1_hr","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,null,null,null,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=linear_interpolation\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, linear_interpolation","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Linear Interpolation","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,7.824999999999999,8.05,8.275,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=nearest_interpolation\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, nearest_interpolation","line":{"color":"#636efa","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nearest Interpolation","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,7.6,7.6,8.5,8.5,18.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %%
_df = df.copy()
_df["spline_interpolation"] = _df['pm2_5_1_hr'].interpolate(method="spline", order=2)
_df["polynomial_interpolation"] = _df['pm2_5_1_hr'].interpolate(method="polynomial", order=5)

# %%
#Plotting
plot_df = pd.melt(_df.reset_index(), id_vars="datetime", var_name="series")
fig = px.line(plot_df, x="datetime", y=["value"], line_dash="series", title="Spline and Polynomial Interpolation")
fig = format_plot(fig, ['Original', "2nd Order Spline Interpolation", "5th Order Polynomial Interpolation"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b360053d-c017-49f8-b9e2-8541b9bebee1" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b360053d-c017-49f8-b9e2-8541b9bebee1")) {                    Plotly.newPlot(                        "b360053d-c017-49f8-b9e2-8541b9bebee1",                        [{"hovertemplate":"variable=value\u003cbr\u003eseries=pm2_5_1_hr\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, pm2_5_1_hr","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,null,null,null,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=spline_interpolation\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, spline_interpolation","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"2nd Order Spline Interpolation","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,7.8460630876084,8.156740773282909,8.934491474753013,8.5,18.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=value\u003cbr\u003eseries=polynomial_interpolation\u003cbr\u003edatetime=%{x}\u003cbr\u003e_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value, polynomial_interpolation","line":{"color":"#636efa","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines","name":"5th Order Polynomial Interpolation","orientation":"v","showlegend":true,"x":["2024-03-20T12:00:00","2024-03-22T03:00:00","2024-03-22T08:00:00","2024-03-24T04:00:00","2024-03-26T09:00:00","2024-03-27T08:00:00","2024-03-27T15:00:00","2024-03-28T07:00:00","2024-03-29T11:00:00","2024-03-31T23:00:00"],"xaxis":"x","y":[0.8,3.3,4.7,6.5,7.6,10.380424210249108,10.994213642635465,11.458565129134078,8.5,18.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0 ...
